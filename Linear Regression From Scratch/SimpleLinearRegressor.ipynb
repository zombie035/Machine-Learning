# %% [markdown]
# # Linear Regression Algorithm from scratch

# %% [markdown]
# ## 🔹 Build Custom Linear Regression Model
# ## Define a Linear Regression class from scratch using mathematical formulas.

# %%
class lr:
    def __init__(self):
        self.m = None
        self.b = None
        
    def fit(self, X_train, y_train):
        n = 0
        d = 0
        
        x_mean = X_train.mean()
        y_mean = y_train.mean()
        
        for i in range(X_train.shape[0]):
            n += (X_train.iloc[i] - x_mean) * (y_train.iloc[i] - y_mean)
            d += (X_train.iloc[i] - x_mean) ** 2
            
        self.m = n / d
        self.b = y_mean - (self.m * x_mean)
        
    def predict(self, X_test):
        return (self.m * X_test) + self.b

# %% [markdown]
# ## Importing the data and Necessary Modules

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("placement.csv")

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %% [markdown]
# # Scatter Plot of cgpa and package

# %%
import matplotlib.pyplot as plt

plt.scatter(df['cgpa'], df['package'])
plt.show()

# %% [markdown]
# ## 🔹 Train-Test Split
# ## Split the dataset into training and testing sets for model evaluation.

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(df["cgpa"],df["package"],test_size = 0.2,random_state = 2)

# %%
X_train.shape
# Out:
# (160,)

# %% [markdown]
# ## 🔹 Train the Model
# ## Fit the custom Linear Regression model on the training data.

# %%
model = lr()
model.fit(X_train, y_train)
# Out:
# array([3.89111601])

# %% [markdown]
# ## 🔹 Make Predictions
# ## Use the trained model to predict values on the test data.

# %%
model.predict(np.array([X_test.iloc[0]]))
# Out:
# array([3.89111601])

# %% [markdown]
# # Slope

# %%
print(model.m)
# Out:
# 0.5579519734250721

# %% [markdown]
# # Intercept

# %%
print(model.b)
# Out:
# -0.8961119222429152

# %% [markdown]
# ## 🔹 Regression Line Visualization
# ## Plot the regression line along with the data points to evaluate model fit.

# %%
import matplotlib.pyplot as plt

# Reset the plot in case plt.xlabel or plt.ylabel were overwritten
plt.figure()

plt.scatter(df['cgpa'], df['package'])
plt.plot(X_train, model.predict(X_train), color='red')

plt.xlabel('cgpa')
plt.ylabel("package")

plt.show()
